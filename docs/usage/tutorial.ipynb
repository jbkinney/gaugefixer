# %% [markdown]
# # User guide
#
# `GaugeFixer` provides a simple interface for fixing the gauge of parameters of linear models that describe sequence-function relationships. These models are implemented as subclasses of `HierarchicalModel`.
#
# ### Defining a linear sequence-function model

# %%
import numpy as np

from gaugefixer import AllOrderModel, PairwiseModel

# %% [markdown]
# To create the most general `HierarchicalModel` object you must specify the configuration of the sequence space describing the sequence→function relationship:
#
# - `L`: sequence length (integer).
# - `alphabet`: sequence alphabet. Options:
#     - a named biological alphabet: `'dna'`, `'rna'`, or `'protein'`;
#     - an explicit list of alleles: `['A','C','G','T']`;
#     - position-specific alphabets: e.g. `[['A','C'], ['A','C','G']]`.
# - `generating_orbits`: set of generating orbits (tuples of position indices). Orbits determine which subsequences share parameters. More specific model classes (e.g., `AllOrderModel`, `KorderModel`, `KadjacentModel`, `PairwiseModel`) provide pre-defined generating orbits for common choices (all orders, up to order k, adjacent-site interactions, pairwise, etc.).
#
# Example: define a 3-nucleotide sequence space with interactions across all possible position subsets (use the AllOrder model):

# %%
model = AllOrderModel(L=3, alphabet_name='dna')
model
# Out:
# AllOrderModel(L=3,alphabet_name=dna,n_features=125,n_orbits=8)

# %% [markdown]
# ### See some model properties
#
# Printing the model already gives a short summary of the model configuration, but we can access other model properties. For instance, we can see the set of generating orbits defining a given hierarchical model

# %%
model.get_generating_orbits()
# Out:
# [(0, 1, 2)]

# %% [markdown]
# We can also access the complete set of orbits and see what is the pattern of interactions across positions in this linear model. In this case, the orbits show that there are interactions of all orders across all possible sets of positions.

# %%
model.get_orbits()
# Out:
# [(), (0,), (1,), (2,), (0, 1), (0, 2), (1, 2), (0, 1, 2)]

# %% [markdown]
# Then, we can extract the sequence features that are associated to each of the orbits. Features are defined by a tuple containing a tuple of the subset of positions and the subsequence at that position, e.g., `((0, 2), 'AG')`. As there are many features, lets just show a few of them.

# %%
model.get_features()[:15]
# Out:
# [((), ''),
#  ((0,), 'A'),
#  ((0,), 'C'),
#  ((0,), 'G'),
#  ((0,), 'T'),
#  ((1,), 'A'),
#  ((1,), 'C'),
#  ((1,), 'G'),
#  ((1,), 'T'),
#  ((2,), 'A'),
#  ((2,), 'C'),
#  ((2,), 'G'),
#  ((2,), 'T'),
#  ((0, 1), 'AA'),
#  ((0, 1), 'AC')]

# %% [markdown]
# ### Defining model parameters
#
# The next step in model definition is to define the values of the model parameters $\theta$. This can be done in different ways.
#
# - `model.set_params(theta)`, where `theta` is a `pd.Series` containing the values associated to every parameter in the model configuration. Parameters must be indexed by a features encoded tuple `(U, u)` containing the position set $U$ and the subsequence $u$. The required features can be accessed via `model.get_features()`.
# - `model.set_basis_coeffs(coeffs)`, where `coeffs` is a `pd.Series` containing the coefficient values associated to specific basis vectors from alternative parametrizations (see [Alternative models](alternative_models.ipynb) for more details).
# - `model.set_landscape(f)`, where `f` is a `pd.Series` containing the phenotype associated to every possible sequence. This method is exclusive to all-order interaction models `AllOrderModel` as we can rarely enumerate all possible sequences in the more general hierarchical models.
# - `model.set_random_params()`. This method initializes the parameter values as a random draw from a standard Gaussian distribution and is only useful for demonstration and testing purposes.
#
# For simplicity, lets just initilalize the parameter values randomly

# %%
model.set_random_params()

# %% [markdown]
# ### Model evaluation
#
# While `GaugeFixer` focuses on transforming the parameters of the models between different gauges and parametrizations, it also enables the evaluation of the sequence-function model for arbitrary sequences by just calling the model directly

# %%
model(['ACG'])
# Out:
# array([0.88098481])

# %% [markdown]
# In the case of all-order interaction models, we can directly evaluate the function for every possible sequence with the `get_landscape` method

# %%
f1 = model.get_landscape()
f1
# Out:
# AAA   -3.705845
# AAC   -0.182447
# AAG   -0.718550
# AAT   -1.062041
# ACA   -5.432000
#          ...
# TGT   -2.177239
# TTA   -3.617061
# TTC   -3.333269
# TTG   -1.486927
# TTT    1.250855
# Length: 64, dtype: float64

# %% [markdown]
# ### Fixing the Gauge
#
# While the model can be evaluated for every possible sequence, the parameters that we randomly defined cannot be directly interpreted because there are unconstrained directions of parameter space that result in the same model predictions, which are known as **gauge freedoms**. Thus, to meaningfully interpret the values of the underlying model parameters, we need to choose one of the many possible set of parameter values, such that the parameters values have speficif mathematical properties and interpretations, a processed called **fixing the gauge**. `GaugeFixer` enables projecting the parameter values into any member of the $\lambda-\pi$ family of linear gauges described by [Posfai et al. (2025)](https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1012818). This family of gauges is parametrized by a scalar $\lambda$ that controls how much variance is explained by lower or higher order terms (larger $\lambda$ values place more variance into lower order terms), and a factorizable distribution over sequences $\pi$ with respect to which this variance is computed. In additional to specifying a gauge directly via the $\lambda,\pi$, `GaugeFixer` also supports previously proposed useful gauges directly
#
# - **Trivial gauge ($\lambda=0$)**. This gauge places all variance explained into the highest-order term, such that parameters $\theta_S^s$, where $S$ is the set of sites and $s$ is a possible sequence directly encode the function for every possible sequence and every other parameter value is set to zero.
# - **Euclidean gauge ($\lambda=\alpha,\pi_l^c=1/\alpha$)**. This gauge chooses the parameter vector $\theta$ that minimizes its euclidean norm. Fitting $L_2$ regularized models with a constant penalty will typicall yield parameters values in this gauge. However, regardless of the inference procedure, parameters values should still be transformed into any desired gauge for interpretation.
# - **Equitable gauge ($\lambda=1$)**. The equitable gauge penalizes each parameter $\theta_U^u$ in proportion to the fraction of sequences that parameter applies to, thus minimizing the sum of the squared norms of the landscape contributions, rather than the squared norm of the parameters.
# - **Hierarchical gauges ($\lambda\to\infty$)**. These gauges place as much variance explained as possible into the lower order terms with respect to the probability distribution $\pi$. Importantly, these gauges preserve the form of hierarchical models and thus enables fixing the gauge in this family of models by retaining only the non-zero parameter values. Within this family, there are also other previously proposed gauges:
#
#     - **Zero-sum gauge ($\pi_l^c=1/\alpha$)**. This gauge chooses a uniform distribution to average over and thus enforces the zero-sum constraint for subsets of parameter values. This gauge is useful for representing allelic contributions to binding energies in transcription factor binding sites or for predicting computing contact maps using pairwise interaction models inferred from sequence diversity data.
#     - **Wild-type gauge ($\pi_l^{s_l}\to 1$ given wild-type sequence $s$)**. In this gauge, parameters represent the phenotype, mutational effect and (pairwise and higher-order) epistatic coefficients relative to that a wild-type sequence $s$.
#
# Projecting the parameter values into any of these gauges can be done simply with the method `get_fixed_params` by specifying the corrresponding gauge.
#
# For instance, lets express our parameters in the commonly used `zero-sum` gauge.

# %%
theta_fixed = model.get_fixed_params(gauge='zero-sum')
theta_fixed
# Out:
# ((), )             -1.071458
# ((0,), A)          -0.157618
# ((0,), C)           0.573875
# ((0,), G)           0.157681
# ((0,), T)          -0.573938
#                       ...
# ((0, 1, 2), TGT)   -0.467775
# ((0, 1, 2), TTA)   -0.608042
# ((0, 1, 2), TTC)   -0.812452
# ((0, 1, 2), TTG)    0.922165
# ((0, 1, 2), TTT)    0.498329
# Length: 125, dtype: float64

# %% [markdown]
# We can verify that, while the new parameter values are different, the two models encode the same function

# %%
model2 = AllOrderModel(L=3, alphabet_name='dna')
model2.set_params(theta_fixed)
f2 = model2.get_landscape()
assert not np.allclose(model.theta, theta_fixed)
assert np.allclose(f1, f2)

# %% [markdown]
# Now the parameters can be more easily interpreted. For example, the parameter for the empty subsequence represents the average across all posible sequences

# %%
theta_fixed.loc[[((), '')]]
# Out:
# ((), )   -1.071458
# dtype: float64

# %% [markdown]
# whereas the parameter associated to nucleotide A at position 2 represents the average effect of placing an A at that position across all possible sequence.

# %%
theta_fixed.loc[[((2,), 'A')]]
# Out:
# ((2,), A)   -1.615967
# dtype: float64

# %% [markdown]
# But maybe we are interested in the effect of placing an A at position 2 only in sequences with A or G at position one. We can do this easily using the `hierarchical` Gauge with a under a site-independent probability distribution `pi_lc`

# %%
pi_lc = [np.array([0.5, 0, 0.5, 0]), np.array([0.25, 0.25, 0.25, 0.25]), np.array([0.25, 0.25, 0.25, 0.25])]
theta_fixed = model.get_fixed_params(gauge='hierarchical', pi_lc=pi_lc)
theta_fixed.loc[[((2,), "A")]]
# Out:
# ((2,), A)   -2.832727
# dtype: float64

# %% [markdown]
# ### Hierarchical models
#
# In the previous case, we have fixed the Gauge in a model in which we can enumerate all possible sequences in the space and have parameter values of all possible orders, which is possible only for sequences of limited length. When having longer sequences, we often fit models that only contain additive, pairwise or, more generally, interactions up to order k, or restrict interactions within a window of adjacent sites in the sequence. These models are specific cases of `HierarchicalModel` with predefined sets of orbits and are implemented as specific classes in `GaugeFixer`, such as `KorderModel` or `KadjacentModel`, which are defined by the highest order interaction `k`.
#
# Let's try with a pairwise model for a 20 aminoacid sequence

# %%
model = PairwiseModel(L=20, alphabet_name='protein')

# %% [markdown]
# As before, we can generate random parameter values

# %%
model.set_random_params()

# %% [markdown]
# and express this model in the `zero-sum` Gauge

# %%
theta_fixed = model.get_fixed_params(gauge='zero-sum')
theta_fixed
# Out:
# ((), )           -1.629986
# ((0,), A)        -0.166241
# ((0,), C)         0.644856
# ((0,), D)        -1.820772
# ((0,), E)        -1.556984
#                     ...
# ((18, 19), YS)   -0.286533
# ((18, 19), YT)    1.365543
# ((18, 19), YV)   -0.894881
# ((18, 19), YW)   -0.118426
# ((18, 19), YY)   -0.311836
# Length: 76401, dtype: float64

# %% [markdown]
# `GaugeFixer`'s new algorithm enables efficient Gauge fixing even in models with hundreds of thousands to few millions parameters. Let's see how long it takes to fix the Gauge of a pairwise model on 100-aminoacid sequences with nearly 2 million parameters.

# %%
model = PairwiseModel(L=100, alphabet_name="protein")
model.set_random_params()

# %%
# %time theta_fixed = model.get_fixed_params(gauge='zero-sum')
# Out:
# CPU times: user 725 ms, sys: 15.4 ms, total: 740 ms
# Wall time: 738 ms
